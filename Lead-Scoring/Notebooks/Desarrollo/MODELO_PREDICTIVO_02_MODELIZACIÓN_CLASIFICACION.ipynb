# %% [markdown]
# # MODELIZACION PARA CLASIFICACION

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.pipeline import Pipeline

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

from sklearn.metrics import classification_report

from sklearn.metrics import PrecisionRecallDisplay


# %config IPCompleter.greedy=True

pd.options.display.float_format = '{:.2f}'.format

import warnings
warnings.filterwarnings("ignore")

# %%
ruta_proyecto = 'C:/Users/mcana/OneDrive/Escritorio/PORTAFOLIO/ML/LEAD_SCORINGLEAD_SCORING_PROYECTO'

# %%
nombre_x = 'x_preseleccionado.pickle'
nombre_y = 'y_preseleccionado.pickle'

# %%
#cargar los datos 
x = pd.read_pickle(ruta_proyecto + '/Datos/tabajo/' + nombre_x)
y = pd.read_pickle(ruta_proyecto + '/Datos/tabajo/' + nombre_y)

# %% [markdown]
# ## MODELIZAR

# %%
train_x,val_x,train_y,val_y = train_test_split(x,y,test_size=0.3)

# %% [markdown]
# ### Crear el Pipe y el diccionario de algoritmos, parámetros y valores a testar

# %%
pipe = Pipeline([('algoritmo',RandomForestClassifier())])

grid = [{'algoritmo': [LogisticRegression()],
         'algoritmo__n_jobs': [-1],
         'algoritmo__solver': ['saga'],
         'algoritmo__penalty': ['elasticnet', 'l1', 'l2', 'none'],
         'algoritmo__C': [0,0.25,0.5,0.75,1]},
        
       ]

# %% [markdown]
# ### Optimizar los hiper parámetros

# %%
grid_search = GridSearchCV(estimator= pipe, 
                            param_grid = grid, 
                            cv = 3, 
                            scoring = 'roc_auc',
                            verbose = 0,
                            n_jobs = -1)

modelo = grid_search.fit(train_x,train_y)

pd.DataFrame(grid_search.cv_results_).sort_values(by = 'rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 17           0.11          0.01             0.01            0.00
# 13           0.11          0.00             0.01            0.00
# 9            0.12          0.01             0.01            0.00
# 18           0.07          0.01             0.01            0.00
# 5            0.11          0.03             0.01            0.00
# 14           0.09          0.00             0.01            0.00
# 10           0.12          0.02             0.01            0.00
# 6            0.07          0.01             0.01            0.00
# 16           0.00          0.00             0.00            0.00
# 15           0.00          0.00             0.00            0.00
# 12           0.00          0.00             0.00            0.00
# 0            0.00          0.00             0.00            0.00
# 8            0.00          0.00             0.00            0.00
# 7            0.01          0.00             0.00            0.00
# 4            0.00          0.00             0.00            0.00
# 3            0.00          0.00             0.00            0.00
# 2            0.00          0.00             0.00            0.00
# 1            0.00          0.00             0.00            0.00
# 11           0.00          0.00             0.00            0.00
# 19           0.00          0.00             0.00            0.00
#
#          param_algoritmo  param_algoritmo__C  param_algoritmo__n_jobs  \
# 17  LogisticRegression()                1.00                       -1
# 13  LogisticRegression()                0.75                       -1
# 9   LogisticRegression()                0.50                       -1
# 18  LogisticRegression()                1.00                       -1
# 5   LogisticRegression()                0.25                       -1
# 14  LogisticRegression()                0.75                       -1
# 10  LogisticRegression()                0.50                       -1
# 6   LogisticRegression()                0.25                       -1
# 16  LogisticRegression()                1.00                       -1
# 15  LogisticRegression()                0.75                       -1
# 12  LogisticRegression()                0.75                       -1
# 0   LogisticRegression()                0.00                       -1
# 8   LogisticRegression()                0.50                       -1
# 7   LogisticRegression()                0.25                       -1
# 4   LogisticRegression()                0.25                       -1
# 3   LogisticRegression()                0.00                       -1
# 2   LogisticRegression()                0.00                       -1
# 1   LogisticRegression()                0.00                       -1
# 11  LogisticRegression()                0.50                       -1
# 19  LogisticRegression()                1.00                       -1
#
#    param_algoritmo__penalty param_algoritmo__solver  \
# 17                       l1                    saga
# 13                       l1                    saga
# 9                        l1                    saga
# 18                       l2                    saga
# 5                        l1                    saga
# 14                       l2                    saga
# 10                       l2                    saga
# 6                        l2                    saga
# 16               elasticnet                    saga
# 15                     none                    saga
# 12               elasticnet                    saga
# 0                elasticnet                    saga
# 8                elasticnet                    saga
# 7                      none                    saga
# 4                elasticnet                    saga
# 3                      none                    saga
# 2                        l2                    saga
# 1                        l1                    saga
# 11                     none                    saga
# 19                     none                    saga
#
#                                                params  split0_test_score  \
# 17  {'algoritmo': LogisticRegression(), 'algoritmo...               0.89
# 13  {'algoritmo': LogisticRegression(), 'algoritmo...               0.89
# 9   {'algoritmo': LogisticRegression(), 'algoritmo...               0.89
# 18  {'algoritmo': LogisticRegression(), 'algoritmo...               0.89
# 5   {'algoritmo': LogisticRegression(), 'algoritmo...               0.89
# 14  {'algoritmo': LogisticRegression(), 'algoritmo...               0.89
# 10  {'algoritmo': LogisticRegression(), 'algoritmo...               0.89
# 6   {'algoritmo': LogisticRegression(), 'algoritmo...               0.89
# 16  {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
# 15  {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
# 12  {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
# 0   {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
# 8   {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
# 7   {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
# 4   {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
# 3   {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
# 2   {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
# 1   {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
# 11  {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
# 19  {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 17               0.85               0.86             0.87            0.01
# 13               0.85               0.86             0.87            0.01
# 9                0.85               0.86             0.87            0.01
# 18               0.85               0.86             0.87            0.02
# 5                0.85               0.86             0.87            0.02
# 14               0.85               0.86             0.87            0.02
# 10               0.85               0.86             0.87            0.02
# 6                0.85               0.85             0.86            0.02
# 16                NaN                NaN              NaN             NaN
# 15                NaN                NaN              NaN             NaN
# 12                NaN                NaN              NaN             NaN
# 0                 NaN                NaN              NaN             NaN
# 8                 NaN                NaN              NaN             NaN
# 7                 NaN                NaN              NaN             NaN
# 4                 NaN                NaN              NaN             NaN
# 3                 NaN                NaN              NaN             NaN
# 2                 NaN                NaN              NaN             NaN
# 1                 NaN                NaN              NaN             NaN
# 11                NaN                NaN              NaN             NaN
# 19                NaN                NaN              NaN             NaN
#
#     rank_test_score
# 17                1
# 13                2
# 9                 3
# 18                4
# 5                 5
# 14                6
# 10                7
# 6                 8
# 16                9
# 15                9
# 12                9
# 0                 9
# 8                 9
# 7                 9
# 4                 9
# 3                 9
# 2                 9
# 1                 9
# 11                9
# 19                9

# %% [markdown]
# ## EVALUAR

# %%
pred = modelo.best_estimator_.predict_proba(val_x) [:,1]

# %%
roc_auc_score(val_y, pred)
# Out:
# 0.8804638062518076

# %% [markdown]
# ###### 0.88 está muy bien, podemos predecir que Leads son los que van a convertir con una capacidad predictiva bastante alta utlizando la R.Logistica

# %%
#Examinar el mejor modelo 
modelo.best_estimator_
# Out:
# Pipeline(steps=[('algoritmo',
#                  LogisticRegression(C=1, n_jobs=-1, penalty='l1',
#                                     solver='saga'))])

# %% [markdown]
# el mejor modelo sería con el coeficiente de penalización de 1; regularización l1; está utilizando el motor de solver saga

# %%
#variables que para nuestro modelo funcionan mejor
modelo.best_estimator_.named_steps.algoritmo.coef_
# Out:
# array([[ 4.09212423,  8.12130309,  1.08684705,  0.        , -1.69932965,
#          2.01784203, -1.55966438,  1.67920183, -0.65832098, -1.37640075,
#         -0.93783071, -1.38252075, -1.70910262, -0.0395892 ,  0.33170004]])

# %%
#acceder a los nombres
modelo.best_estimator_.named_steps.algoritmo.feature_names_in_
# Out:
# array(['tiempo_en_site_total_mms', 'score_actividad_mms',
#        'ult_actividad_SMS Sent', 'visitas_total_mms',
#        'paginas_vistas_visita_mms', 'score_perfil_mms', 'ambito_Select',
#        'ocupacion_Working Professional', 'ocupacion_Unemployed',
#        'ult_actividad_Converted to Lead',
#        'ult_actividad_Page Visited on Website',
#        'ult_actividad_Chat Conversation',
#        'origen_Landing Page Submission', 'fuente_Google',
#        'descarga_lm_No'], dtype=object)

# %%
pd.DataFrame(data = modelo.best_estimator_.named_steps.algoritmo.coef_,
            columns= modelo.best_estimator_.named_steps.algoritmo.feature_names_in_)
# Out:
#    tiempo_en_site_total_mms  score_actividad_mms  ult_actividad_SMS Sent  \
# 0                      4.09                 8.12                    1.09
#
#    visitas_total_mms  paginas_vistas_visita_mms  score_perfil_mms  \
# 0               0.00                      -1.70              2.02
#
#    ambito_Select  ocupacion_Working Professional  ocupacion_Unemployed  \
# 0          -1.56                            1.68                 -0.66
#
#    ult_actividad_Converted to Lead  ult_actividad_Page Visited on Website  \
# 0                            -1.38                                  -0.94
#
#    ult_actividad_Chat Conversation  origen_Landing Page Submission  \
# 0                            -1.38                           -1.71
#
#    fuente_Google  descarga_lm_No
# 0          -0.04            0.33

# %%
pd.DataFrame(data = modelo.best_estimator_.named_steps.algoritmo.coef_,
            columns= modelo.best_estimator_.named_steps.algoritmo.feature_names_in_).unstack().sort_values(ascending=False)
# Out:
# score_actividad_mms                    0    8.12
# tiempo_en_site_total_mms               0    4.09
# score_perfil_mms                       0    2.02
# ocupacion_Working Professional         0    1.68
# ult_actividad_SMS Sent                 0    1.09
# descarga_lm_No                         0    0.33
# visitas_total_mms                      0    0.00
# fuente_Google                          0   -0.04
# ocupacion_Unemployed                   0   -0.66
# ult_actividad_Page Visited on Website  0   -0.94
# ult_actividad_Converted to Lead        0   -1.38
# ult_actividad_Chat Conversation        0   -1.38
# ambito_Select                          0   -1.56
# paginas_vistas_visita_mms              0   -1.70
# origen_Landing Page Submission         0   -1.71
# dtype: float64
